# %% [markdown]
# <a href="https://colab.research.google.com/github/yejinPARK48/michigan_building_detection/blob/main/06_Puma_estimation/Phase6_2603203_2601703_2602903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Small PUMA Group — Building Estimation (sequential)
#
# Processes the remaining small PUMAs in one run, each saved to its own files
# (`tile_predictions_puma_<code>.csv`, `bg_estimates_puma_<code>.csv`). Already
# finished PUMAs are skipped, so a disconnect resumes cleanly. Sequential is fine
# here because each PUMA is only ~1.4k-2.7k tiles.

# %% [markdown]
# ## 0. Setup

# %%
# SSL patch MUST be first, before any other network imports
import os, ssl, urllib3
os.environ['CURL_CA_BUNDLE']     = ''
os.environ['REQUESTS_CA_BUNDLE'] = ''
ssl._create_default_https_context = ssl._create_unverified_context
urllib3.disable_warnings()

# %%
# !pip install pystac-client planetary-computer rasterio geopandas shapely pyogrio -q
# !pip install segmentation-models-pytorch albumentations opencv-python-headless scikit-image -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.9 MB/s eta 0:00:00

# %%
import os, warnings, zipfile, urllib.request, time, shutil, json
warnings.filterwarnings('ignore')
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import geopandas as gpd
from pyproj import Transformer
from PIL import Image
from shapely.geometry import box, Point, shape as shapely_shape
from shapely.ops import transform as shp_transform
from shapely.prepared import prep
from skimage import measure

import rasterio
from rasterio.windows import from_bounds
from rasterio.enums import Resampling
from rasterio.crs import CRS
from rasterio.warp import transform_bounds

import pystac_client
import planetary_computer as pc
from google.colab import userdata
pc.settings.set_subscription_key(userdata.get('PC_KEY'))

import torch
from torch.utils.data import Dataset, DataLoader
import segmentation_models_pytorch as smp
import albumentations as A
from albumentations.pytorch import ToTensorV2

from google.colab import drive
drive.mount('/content/drive')

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', DEVICE)
# Out:
# Mounted at /content/drive
# Device: cpu

# %% [markdown]
# ## 1. Config

# %%
PUMAS_9 = [
    '2601200', '2603203', '2600100', '2602903', '2600802',
    '2603212', '2601701', '2601703', '2601600',
]

BASE_DIR      = '/content/drive/MyDrive/michigan_unet_project'
CKPT_DIR      = f'{BASE_DIR}/checkpoints'
SEG_CKPT      = f'{CKPT_DIR}/unet_seg_best_full_curated.pt'

PRED_DIR      = f'{BASE_DIR}/results_9puma/predictions_puma'
PROGRESS_DIR  = f'{BASE_DIR}/results_9puma/progress_puma'
GEO_DIR       = f'{BASE_DIR}/geo'

for d in [PRED_DIR, PROGRESS_DIR, GEO_DIR]:
    os.makedirs(d, exist_ok=True)

TILE_SIZE_M    = 256
TILE_SIZE_PX   = 512
UTM_EPSG       = 26917
NAIP_YEAR      = 2020
BEST_THRESHOLD = 0.5
BEST_MIN_AREA  = 50

TILE_AREA_KM2 = (TILE_SIZE_M ** 2) / 1e6          # ground area per tile
PIXEL_AREA_M2 = (TILE_SIZE_M / TILE_SIZE_PX) ** 2  # ground area per pixel

DENSE_THRESHOLD  = 0.05
SPARSE_THRESHOLD = 0.001
def classify_tier(ratio):
    if ratio >= DENSE_THRESHOLD:    return 'Dense'
    elif ratio >= SPARSE_THRESHOLD: return 'Sparse'
    else:                           return 'Empty'

print('Checkpoint exists:', os.path.exists(SEG_CKPT))
# Out:
# Checkpoint exists: True

# %% [markdown]
# ## 2. Load PUMA boundaries + ranking (once)

# %%
def fetch_tiger(candidate_urls, local_zip, extract_dir):
    # download the first reachable TIGER zip, extract, return dir
    if any(f.endswith('.shp') for f in os.listdir(extract_dir)):
        return extract_dir
    last = None
    for url in candidate_urls:
        try:
            print('Trying', url)
            urllib.request.urlretrieve(url, local_zip)
            with zipfile.ZipFile(local_zip) as z:
                z.extractall(extract_dir)
            return extract_dir
        except Exception as e:
            last = e
            print('  failed:', e)
    raise RuntimeError(f'all PUMA URLs failed: {last}')

PUMA_DIR = f'{GEO_DIR}/puma20'
os.makedirs(PUMA_DIR, exist_ok=True)
fetch_tiger(
    candidate_urls=[
        'https://www2.census.gov/geo/tiger/TIGER2023/PUMA20/tl_2023_26_puma20.zip',
        'https://www2.census.gov/geo/tiger/TIGER2022/PUMA20/tl_2022_26_puma20.zip',
        'https://www2.census.gov/geo/tiger/TIGER2024/PUMA20/tl_2024_26_puma20.zip',
    ],
    local_zip=f'{PUMA_DIR}/puma20.zip',
    extract_dir=PUMA_DIR,
)
puma_shp = [f'{PUMA_DIR}/{f}' for f in os.listdir(PUMA_DIR) if f.endswith('.shp')][0]
gdf_puma_all = gpd.read_file(puma_shp)
geoid_col = next(c for c in gdf_puma_all.columns if c.upper().startswith('GEOID'))
aland_col = next((c for c in gdf_puma_all.columns if c.upper().startswith('ALAND')), None)
gdf_puma_all[geoid_col] = gdf_puma_all[geoid_col].astype(str)

_r = gdf_puma_all[gdf_puma_all[geoid_col].isin(PUMAS_9)].copy()
if aland_col:
    _r['area_km2'] = _r[aland_col] / 1e6
else:
    _r['area_km2'] = _r.to_crs(epsg=UTM_EPSG).geometry.area / 1e6
_r = _r[[geoid_col, 'area_km2']].sort_values('area_km2').reset_index(drop=True)
_r['est_tiles'] = (_r['area_km2'] * 1e6 / (TILE_SIZE_M ** 2)).round().astype(int)
print('9 PUMAs ranked smallest -> largest:')
print(_r.to_string(index=False))
# Out:
# 9 PUMAs ranked smallest -> largest:
# GEOID20     area_km2  est_tiles
# 2603212    65.106587        993
# 2603203    93.779840       1431
# 2601703   163.192431       2490
# 2602903   177.935191       2715
# 2600802   846.509173      12917
# 2601701  2131.045270      32517
# 2601200  4417.097111      67400
# 2601600  6742.852277     102888
# 2600100 22265.787264     339749

# %% [markdown]
# ## 3. Load statewide block groups (once)

# %%
SHP_BG = f'{BASE_DIR}/tl_2020_26_bg.shp'
if not os.path.exists(SHP_BG):
    print('Block-group shapefile not in Drive - downloading...')
    urllib.request.urlretrieve(
        'https://www2.census.gov/geo/tiger/TIGER2020/BG/tl_2020_26_bg.zip',
        '/content/tl_2020_26_bg.zip')
    with zipfile.ZipFile('/content/tl_2020_26_bg.zip') as z:
        z.extractall(BASE_DIR)

gdf_bg = gpd.read_file(SHP_BG).to_crs(epsg=4326)
gdf_bg = gdf_bg.rename(columns={'GEOID': 'bg_geoid'})
gdf_bg['bg_geoid'] = gdf_bg['bg_geoid'].astype(str)
print('Statewide block groups loaded:', len(gdf_bg))
# Out:
# Statewide block groups loaded: 8386

# %% [markdown]
# ## 4. Load model (once)

# %%
model = smp.Unet(encoder_name='resnet34', encoder_weights=None,
                 in_channels=3, classes=1, activation=None).to(DEVICE)
model.load_state_dict(torch.load(SEG_CKPT, map_location=DEVICE))
model.eval()
print('Model loaded.')

val_aug = A.Compose([
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

class InferenceDataset(Dataset):
    def __init__(self, tile_ids, img_dir, transform=None):
        self.tile_ids, self.img_dir, self.transform = tile_ids, img_dir, transform
    def __len__(self): return len(self.tile_ids)
    def __getitem__(self, idx):
        tid = self.tile_ids[idx]
        img = np.array(Image.open(f'{self.img_dir}/{tid}.png').convert('RGB'))
        if self.transform:
            img = self.transform(image=img)['image']
        return img, tid

def count_and_area(pred_mask):
    # building count + footprint area (m^2) for components >= BEST_MIN_AREA px
    labeled = measure.label(pred_mask)
    count, area_px = 0, 0
    for r in measure.regionprops(labeled):
        if r.area >= BEST_MIN_AREA:
            count += 1
            area_px += r.area
    return count, area_px * PIXEL_AREA_M2
# Out:
# Model loaded.

# %% [markdown]
# ## 5. Helper functions + aggregation

# %%
def get_naip_items(bbox, year=NAIP_YEAR, max_items=4000):
    catalog = pystac_client.Client.open(
        'https://planetarycomputer.microsoft.com/api/stac/v1', modifier=pc.sign_inplace)
    items = catalog.search(collections=['naip'], bbox=bbox,
                           datetime=f'{year}-01-01/{year}-12-31',
                           max_items=max_items).item_collection()
    if len(items) == 0:
        items = catalog.search(collections=['naip'], bbox=bbox,
                               max_items=max_items).item_collection()
    return list(items)

def build_item_index(items):
    recs = []
    for it in items:
        try:
            recs.append({'item_id': it.id,
                         'href': it.assets['image'].href,
                         'geometry': shapely_shape(it.geometry)})
        except Exception:
            continue
    return gpd.GeoDataFrame(recs, geometry='geometry', crs='EPSG:4326')

def crop_tile_from_src(src, bbox, size_px=TILE_SIZE_PX):
    try:
        bt = transform_bounds(CRS.from_epsg(4326), src.crs, *bbox)
        window = from_bounds(*bt, transform=src.transform)
        data = src.read([1, 2, 3], window=window, out_shape=(3, size_px, size_px),
                        resampling=Resampling.bilinear)
        return np.transpose(data, (1, 2, 0)).astype(np.uint8)
    except Exception:
        return None

def fetch_naip_tile(bbox, year=NAIP_YEAR, size_px=TILE_SIZE_PX, max_retries=3):
    for attempt in range(max_retries):
        try:
            catalog = pystac_client.Client.open(
                'https://planetarycomputer.microsoft.com/api/stac/v1', modifier=pc.sign_inplace)
            items = catalog.search(collections=['naip'], bbox=bbox,
                                   datetime=f'{year}-01-01/{year}-12-31',
                                   max_items=5).item_collection()
            if len(items) == 0:
                items = catalog.search(collections=['naip'], bbox=bbox,
                                       max_items=5).item_collection()
                if len(items) == 0:
                    return None
            href = pc.sign(items[0].assets['image'].href)
            with rasterio.open(href) as src:
                return crop_tile_from_src(src, bbox, size_px)
        except Exception:
            if attempt < max_retries - 1:
                time.sleep(2)
            else:
                return None
    return None

def build_puma_tiles(puma_code, puma_geom, gdf_bg_puma,
                     tile_size_m=TILE_SIZE_M, crs_utm=UTM_EPSG):
    # one regular grid over the PUMA polygon; keep tiles whose centroid is inside
    to_utm = Transformer.from_crs('EPSG:4326', f'EPSG:{crs_utm}', always_xy=True).transform
    to_wgs = Transformer.from_crs(f'EPSG:{crs_utm}', 'EPSG:4326', always_xy=True).transform
    geom_utm = shp_transform(to_utm, puma_geom)
    pgeom = prep(geom_utm)
    minx, miny, maxx, maxy = geom_utm.bounds

    rows, seq, x = [], 0, minx
    while x < maxx:
        y = miny
        while y < maxy:
            cx, cy = x + tile_size_m / 2, y + tile_size_m / 2
            if pgeom.contains(Point(cx, cy)):
                wx0, wy0 = to_wgs(x, y)
                wx1, wy1 = to_wgs(x + tile_size_m, y + tile_size_m)
                wcx, wcy = to_wgs(cx, cy)
                rows.append((f'{puma_code}_{seq:06d}',
                             min(wx0, wx1), min(wy0, wy1), max(wx0, wx1), max(wy0, wy1),
                             wcx, wcy))
                seq += 1
            y += tile_size_m
        x += tile_size_m

    df = pd.DataFrame(rows, columns=['tile_id', 'minx', 'miny', 'maxx', 'maxy', 'cx', 'cy'])
    gt = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['cx'], df['cy']), crs='EPSG:4326')
    j = gpd.sjoin(gt[['tile_id', 'geometry']],
                  gdf_bg_puma[['bg_geoid', 'county_fips', 'geometry']],
                  how='left', predicate='within')
    j = j[~j.index.duplicated(keep='first')]
    gt['bg_geoid']    = j['bg_geoid'].values
    gt['county_fips'] = j['county_fips'].values
    gt = gt.dropna(subset=['bg_geoid']).reset_index(drop=True)
    gt['bbox'] = list(zip(gt['minx'], gt['miny'], gt['maxx'], gt['maxy']))
    return gt

def aggregate_bg(puma_code, gdf_bg_puma, pred_path, bg_path):
    if not os.path.exists(pred_path):
        print(f'[{puma_code}] no predictions to aggregate')
        return
    _proj = gdf_bg_puma.to_crs(epsg=UTM_EPSG)
    bg_area = pd.DataFrame({'bg_geoid': gdf_bg_puma['bg_geoid'].values,
                            'county_fips': gdf_bg_puma['county_fips'].values,
                            'area_km2': _proj.geometry.area.values / 1e6})
    df = pd.read_csv(pred_path, dtype={'bg_geoid': str, 'county_fips': str})
    bg = (df.groupby('bg_geoid')
            .agg(n_tiles=('tile_id', 'count'),
                 pred_buildings=('pred_count', 'sum'),
                 mask_area_m2=('mask_area_m2', 'sum'),
                 mean_mask_ratio=('mask_ratio', 'mean'),
                 dense_tiles=('tier', lambda s: (s == 'Dense').sum()),
                 sparse_tiles=('tier', lambda s: (s == 'Sparse').sum()),
                 empty_tiles=('tier', lambda s: (s == 'Empty').sum()))
            .reset_index())
    bg = bg.merge(bg_area, on='bg_geoid', how='left')
    bg['puma'] = puma_code
    bg['mask_area_km2']        = bg['mask_area_m2'] / 1e6
    bg['tiled_area_km2']       = bg['n_tiles'] * TILE_AREA_KM2
    bg['built_fraction']       = bg['mask_area_km2'] / bg['area_km2']
    bg['built_pct']            = bg['built_fraction'] * 100
    bg['building_density_km2'] = bg['pred_buildings'] / bg['area_km2']
    for col, nd in [('area_km2', 4), ('tiled_area_km2', 4), ('mask_area_km2', 5),
                    ('built_fraction', 5), ('built_pct', 2),
                    ('building_density_km2', 2), ('mean_mask_ratio', 6)]:
        bg[col] = bg[col].round(nd)
    bg = bg[['puma', 'bg_geoid', 'county_fips', 'area_km2', 'tiled_area_km2',
             'pred_buildings', 'building_density_km2', 'mask_area_km2',
             'built_fraction', 'built_pct', 'n_tiles', 'mean_mask_ratio',
             'dense_tiles', 'sparse_tiles', 'empty_tiles']]
    bg.to_csv(bg_path, index=False)
    tb, ta, tm = bg['pred_buildings'].sum(), bg['area_km2'].sum(), bg['mask_area_km2'].sum()
    print(f'[{puma_code}] -> {bg_path}')
    print(f'[{puma_code}] buildings {tb:,} | land {ta:.1f} km^2 | '
          f'density {tb/ta:.1f}/km^2 | built-up {100*tm/ta:.2f}%')

# %% [markdown]
# ## 6. process_puma() — full per-PUMA pipeline

# %%
def process_puma(puma_code, parallel=False, workers=8):
    pred_path     = f'{PRED_DIR}/tile_predictions_puma_{puma_code}.csv'
    bg_path       = f'{PRED_DIR}/bg_estimates_puma_{puma_code}.csv'
    progress_path = f'{PROGRESS_DIR}/done_images_{puma_code}.json'
    img_dir       = f'/content/tiles_tmp/{puma_code}'

    if os.path.exists(bg_path):
        print(f'[{puma_code}] already complete; skipping')
        return

    sel = gdf_puma_all[gdf_puma_all[geoid_col] == puma_code]
    if len(sel) == 0:
        print(f'[{puma_code}] not found in PUMA shapefile; skipping')
        return
    puma_geom = sel.to_crs(epsg=4326).iloc[0].geometry

    bg_c = gdf_bg.copy()
    bg_c['geometry'] = gdf_bg.geometry.centroid
    gdf_bg_puma = gdf_bg[bg_c.geometry.within(puma_geom)].reset_index(drop=True)
    gdf_bg_puma['county_fips'] = '26' + gdf_bg_puma['bg_geoid'].str[2:5]

    gdf_tiles = build_puma_tiles(puma_code, puma_geom, gdf_bg_puma)
    print(f'[{puma_code}] block groups {len(gdf_bg_puma)} | tiles {len(gdf_tiles):,}')
    if len(gdf_tiles) == 0:
        return

    naip_items = get_naip_items(puma_geom.bounds)
    gdf_items  = build_item_index(naip_items)
    cent = gdf_tiles[['tile_id', 'geometry']].copy()
    ti = gpd.sjoin(cent, gdf_items[['item_id', 'geometry']], how='left', predicate='within')
    ti = ti[~ti.index.duplicated(keep='first')]
    gdf_tiles['item_id'] = ti['item_id'].values
    n_assigned = gdf_tiles['item_id'].notna().sum()
    print(f'[{puma_code}] NAIP images {len(gdf_items)} | assigned {n_assigned:,} | '
          f'fallback {len(gdf_tiles) - n_assigned:,}')

    done_images = set(json.load(open(progress_path))) if os.path.exists(progress_path) else set()
    done_tiles  = set(pd.read_csv(pred_path, usecols=['tile_id'])['tile_id']) if os.path.exists(pred_path) else set()
    tile_meta = gdf_tiles.set_index('tile_id')[['bg_geoid', 'county_fips']]

    def append_predictions(rows):
        if not rows:
            return
        d = pd.DataFrame(rows).join(tile_meta, on='tile_id')
        d['puma'] = puma_code
        d = d[['tile_id', 'puma', 'bg_geoid', 'county_fips',
               'pred_count', 'mask_area_m2', 'mask_ratio', 'tier']]
        d.to_csv(pred_path, mode='a', header=not os.path.exists(pred_path), index=False)

    def predict_saved(tids):
        if not tids:
            return []
        ld = DataLoader(InferenceDataset(tids, img_dir, val_aug),
                        batch_size=16, shuffle=False, num_workers=2)
        out = []
        with torch.no_grad():
            for imgs, t in ld:
                probs  = torch.sigmoid(model(imgs.to(DEVICE)))
                masks  = (probs > BEST_THRESHOLD).cpu().numpy()
                ratios = masks.reshape(masks.shape[0], -1).mean(axis=1)
                for b in range(len(t)):
                    cnt, area = count_and_area(masks[b, 0])
                    out.append({'tile_id': t[b], 'pred_count': cnt,
                                'mask_area_m2': round(area, 2),
                                'mask_ratio': round(float(ratios[b]), 6),
                                'tier': classify_tier(float(ratios[b]))})
        return out

    def download_group(item_id, grp):
        href = None
        if item_id is not None and not (isinstance(item_id, float) and np.isnan(item_id)):
            hh = gdf_items.loc[gdf_items['item_id'] == item_id, 'href']
            href = hh.iloc[0] if len(hh) else None
        src = None
        if href is not None:
            try:
                src = rasterio.open(pc.sign(href))
            except Exception:
                src = None
        saved = []
        for _, r in grp.iterrows():
            tid = r['tile_id']
            if tid in done_tiles:
                continue
            img = crop_tile_from_src(src, r['bbox']) if src is not None else None
            if img is None or img.sum() == 0:
                img = fetch_naip_tile(r['bbox'])
            if img is None:
                continue
            Image.fromarray(img).save(f'{img_dir}/{tid}.png')
            saved.append(tid)
        if src is not None:
            src.close()
        return saved

    def flush(saved, finished):
        append_predictions(predict_saved(saved))
        done_tiles.update(saved)
        done_images.update(finished)
        json.dump(sorted(str(x) for x in done_images), open(progress_path, 'w'))

    groups = [(iid, g) for iid, g in gdf_tiles.groupby('item_id', dropna=False)]
    total = len(groups)
    shutil.rmtree(img_dir, ignore_errors=True); os.makedirs(img_dir, exist_ok=True)

    if parallel:
        pending = [(iid, g) for iid, g in groups if str(iid) not in done_images]
        for s in range(0, len(pending), workers):
            chunk = pending[s:s + workers]
            saved_all = []
            with ThreadPoolExecutor(max_workers=workers) as ex:
                for fut in [ex.submit(download_group, iid, g) for iid, g in chunk]:
                    saved_all.extend(fut.result())
            flush(saved_all, [str(iid) for iid, _ in chunk])
            shutil.rmtree(img_dir, ignore_errors=True); os.makedirs(img_dir, exist_ok=True)
            print(f'[{puma_code}] {min(s + workers, len(pending))}/{len(pending)} '
                  f'image-groups | +{len(saved_all):,} tiles')
    else:
        for gi, (iid, g) in enumerate(groups, 1):
            if str(iid) in done_images:
                continue
            saved = download_group(iid, g)
            flush(saved, [str(iid)])
            shutil.rmtree(img_dir, ignore_errors=True); os.makedirs(img_dir, exist_ok=True)
            print(f'[{puma_code}] [{gi}/{total}] image {iid} | +{len(saved):,} tiles')

    shutil.rmtree(img_dir, ignore_errors=True)
    aggregate_bg(puma_code, gdf_bg_puma, pred_path, bg_path)
    print(f'[{puma_code}] DONE')

# %% [markdown]
# ## 7. Run — small PUMA group

# %%
# remaining small PUMAs (< 200 km^2, ~1.4k-2.7k tiles each)
PUMAS_SMALL = ['2603203', '2601703', '2602903']

for code in PUMAS_SMALL:
    print('=' * 60)
    print('PUMA', code)
    print('=' * 60)
    process_puma(code, parallel=False)

print('')
print('Small-group session complete.')
# Out:
# ============================================================
# PUMA 2603203
# ============================================================
# [2603203] block groups 129 | tiles 1,446
# [2603203] NAIP images 10 | assigned 1,446 | fallback 0
# [2603203] [1/8] image mi_m_4208346_ne_17_060_20200705 | +262 tiles
# [2603203] [2/8] image mi_m_4208346_nw_17_060_20200705 | +34 tiles
# [2603203] [3/8] image mi_m_4208346_se_17_060_20200705 | +273 tiles
# [2603203] [4/8] image mi_m_4208346_sw_17_060_20200705 | +5 tiles
# [2603203] [5/8] image mi_m_4208347_ne_17_060_20200705 | +153 tiles
# [2603203] [6/8] image mi_m_4208347_nw_17_060_20200705 | +233 tiles
# [2603203] [7/8] image mi_m_4208347_se_17_060_20200705 | +140 tiles
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-144308885 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 157652741-158409185 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-144308885 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 157652741-158409185 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 129512415-130291517 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-144308885 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 129512415-130291517 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-144308885 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 343130077-343919965 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 357638652-358393912 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 343130077-343919965 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 357638652-358393912 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-314760205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 328555253-329338409 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-314760205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 328555253-329338409 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300161204 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-314760205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300161204 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-314760205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-285585611 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300161204 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-285585611 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300161204 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 270153123-270934490 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-285585611 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 270153123-270934490 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-285585611 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242180324 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 255638775-256417773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242180324 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 255638775-256417773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-228548561 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242180324 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-228548561 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242180324 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215059632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-228548561 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215059632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-228548561 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 200640476-201436946 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215059632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 200640476-201436946 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215059632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173184107 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 186607825-187344762 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173184107 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 186607825-187344762 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 157652741-159182681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173184107 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 157652741-159182681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173184107 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-145056911 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 158409182-159182681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 143581344-145056911 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 158409182-159182681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 130291514-131066557 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 144308882-145056911 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 130291514-131066557 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 144308882-145056911 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 343919962-344699922 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 357638652-359151658 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 343919962-344699922 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 357638652-359151658 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-315540563 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 329338406-330068226 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 313973497-315540563 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 329338406-330068226 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300928566 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 314760202-315540563 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 299395834-300928566 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 314760202-315540563 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-286375341 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300161201-300928566 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 284788193-286375341 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300161201-300928566 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 270934487-271696031 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 285585608-286375341 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 270934487-271696031 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 285585608-286375341 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242900985 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 256417770-257155657 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 241474244-242900985 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 256417770-257155657 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-229250940 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242180321-242900985 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 227831423-229250940 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242180321-242900985 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215769037 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 228548558-229250940 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 214297078-215769037 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 228548558-229250940 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 201436943-202122801 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215059629-215769037 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 201436943-202122801 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215059629-215769037 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173895371 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 187344759-188034677 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 172441038-173895371 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 187344759-188034677 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 158409182-159931664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173184104-173895371 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 158409182-159931664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173184104-173895371 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 144308882-145827199 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159182678-159931664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 144308882-145827199 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159182678-159931664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 131066554-131827271 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145056908-145827199 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 131066554-131827271 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145056908-145827199 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 344699919-345479454 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 358393909-359891495 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 344699919-345479454 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 358393909-359891495 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 314760202-316310261 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 330068223-330844126 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 314760202-316310261 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 330068223-330844126 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300161201-301699580 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 315540560-316310261 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300161201-301699580 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 315540560-316310261 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 285585608-287117488 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300928563-301699580 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 285585608-287117488 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 300928563-301699580 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 271696028-272464065 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 286375338-287117488 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 271696028-272464065 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 286375338-287117488 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242180321-243610313 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 257155654-257847315 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242180321-243610313 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 257155654-257847315 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 228548558-229937809 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242900982-243610313 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 228548558-229937809 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 242900982-243610313 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215059629-216429827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229250937-229937809 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215059629-216429827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229250937-229937809 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 202122798-202804935 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215769034-216429827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 202122798-202804935 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 215769034-216429827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173184104-174601939 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 188034674-188721056 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173184104-174601939 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 188034674-188721056 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159182678-160649867 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173895368-174601939 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159182678-160649867 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 173895368-174601939 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145056908-146570146 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159931661-160649867 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145056908-146570146 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 159931661-160649867 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 131827268-132569279 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145827196-146570146 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 131827268-132569279 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 145827196-146570146 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 345479451-346241945 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 359151655-360621984 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 345479451-346241945 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 359151655-360621984 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317076614 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 330844123-331604048 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317076614 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 330844123-331604048 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-302457549 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317076614 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-302457549 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317076614 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-287872717 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-302457549 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-287872717 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-302457549 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 272464062-273239579 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-287872717 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 272464062-273239579 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-287872717 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-244317891 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 257847312-258597724 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-244317891 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 257847312-258597724 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-230592726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-244317891 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-230592726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-244317891 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217094773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-230592726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217094773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-230592726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 202804932-203486548 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217094773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 202804932-203486548 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217094773 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-175325180 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 188721053-189450518 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-175325180 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 188721053-189450518 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-161357599 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-175325180 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-161357599 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-175325180 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-147312339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-161357599 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-147312339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-161357599 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 132569276-133313623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-147312339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 132569276-133313623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-147312339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 346241942-347005394 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 359891492-361350231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 346241942-347005394 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 359891492-361350231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317843690 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 331604045-332349463 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 316310258-317843690 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 331604045-332349463 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-303227608 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317076611-317843690 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 301699577-303227608 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317076611-317843690 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-288632642 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 302457546-303227608 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287117485-288632642 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 302457546-303227608 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 273239576-274015434 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287872714-288632642 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 273239576-274015434 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287872714-288632642 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-245058910 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 258597721-259376681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 243610310-245058910 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 258597721-259376681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-231293231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 244317888-245058910 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 229937806-231293231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 244317888-245058910 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217785051 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 230592723-231293231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 216429824-217785051 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 230592723-231293231 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 203486545-204134802 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217094770-217785051 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 203486545-204134802 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217094770-217785051 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-176052767 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 189450515-190094708 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 174601936-176052767 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 189450515-190094708 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-162064043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 175325177-176052767 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 160649864-162064043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 175325177-176052767 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-148049046 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 161357596-162064043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 146570143-148049046 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 161357596-162064043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 133313620-134030255 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 147312336-148049046 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 133313620-134030255 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 147312336-148049046 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 347005391-347754355 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 360621981-362085133 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 347005391-347754355 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 360621981-362085133 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317076611-318615535 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 332349460-333102831 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317076611-318615535 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 332349460-333102831 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 302457546-303988247 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317843687-318615535 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 302457546-303988247 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317843687-318615535 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287872714-289395115 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303227605-303988247 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 287872714-289395115 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303227605-303988247 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 274015431-274762895 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 288632639-289395115 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 274015431-274762895 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 288632639-289395115 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 244317888-245781167 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 259376678-260132467 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 244317888-245781167 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 259376678-260132467 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 230592723-231947703 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245058907-245781167 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 230592723-231947703 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245058907-245781167 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217094770-218430354 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231293228-231947703 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217094770-218430354 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231293228-231947703 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 204134799-204766577 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217785048-218430354 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 204134799-204766577 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217785048-218430354 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 175325177-176789656 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 190094705-190799544 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 175325177-176789656 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 190094705-190799544 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 161357596-162759026 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176052764-176789656 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 161357596-162759026 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176052764-176789656 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 147312336-148736788 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162064040-162759026 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 147312336-148736788 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162064040-162759026 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 134030252-134678272 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148049043-148736788 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 134030252-134678272 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148049043-148736788 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 332349460-333850662 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 347754352-348504242 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 332349460-333850662 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 347754352-348504242 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317843687-319386726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 333102828-333850662 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 317843687-319386726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 333102828-333850662 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303227605-304771628 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 318615532-319386726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303227605-304771628 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 318615532-319386726 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 288632639-290175140 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303988244-304771628 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 288632639-290175140 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303988244-304771628 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 274762892-275543158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 289395112-290175140 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 274762892-275543158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 289395112-290175140 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245058907-246520659 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 260132464-260903476 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245058907-246520659 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 260132464-260903476 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231293228-232590596 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245781164-246520659 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231293228-232590596 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245781164-246520659 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217785048-219000884 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231947700-232590596 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 217785048-219000884 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231947700-232590596 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 204766574-205361219 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 218430351-219000884 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 204766574-205361219 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 218430351-219000884 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176052764-177501746 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 190799541-191503807 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176052764-177501746 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 190799541-191503807 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162064040-163448681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176789653-177501746 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162064040-163448681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176789653-177501746 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148049043-149455403 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162759023-163448681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148049043-149455403 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162759023-163448681 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 134678269-135308582 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148736785-149455403 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 134678269-135308582 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148736785-149455403 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 318615532-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 333102828-334586282 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 318615532-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 333102828-334586282 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303988244-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 319386723-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 303988244-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 319386723-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 289395112-290953590 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 304771625-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 289395112-290953590 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 304771625-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 275543155-276296484 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 290175137-290953590 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 275543155-276296484 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 290175137-290953590 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245781164-247281498 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 260903473-261655696 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 245781164-247281498 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 260903473-261655696 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231947700-233216411 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 246520656-247281498 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 231947700-233216411 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 246520656-247281498 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 218430351-219538018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 232590593-233216411 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 218430351-219538018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 232590593-233216411 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 205361216-205934467 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219000881-219538018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 205361216-205934467 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219000881-219538018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176789653-178202393 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 191503804-192187627 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 176789653-178202393 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 191503804-192187627 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162759023-164128202 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 177501743-178202393 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 162759023-164128202 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 177501743-178202393 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148736785-150153676 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 163448678-164128202 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 148736785-150153676 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 163448678-164128202 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 135308579-136041622 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 149455400-150153676 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 135308579-136041622 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 149455400-150153676 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 304771625-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 319386723-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 304771625-305540738 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 319386723-320113575 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 276296481-277071028 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 290953587-291701156 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 276296481-277071028 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 290953587-291701156 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-247991170 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 261655693-262424667 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-247991170 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 261655693-262424667 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-233852872 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-247991170 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-233852872 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-247991170 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219538015-220148501 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-233852872 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219538015-220148501 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-233852872 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 205934464-206513551 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219538015-220148501 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 205934464-206513551 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219538015-220148501 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 178202390-178901339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 192187624-192827784 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 178202390-178901339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 192187624-192827784 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 164128199-164828623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 178202390-178901339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 164128199-164828623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 178202390-178901339 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 150153673-150816956 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 164128199-164828623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 150153673-150816956 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 164128199-164828623 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 136041619-136726005 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 150153673-150816956 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 136041619-136726005 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 150153673-150816956 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 261655693-263172368 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 277071025-277790593 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 261655693-263172368 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 277071025-277790593 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-248688043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 262424664-263172368 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247281495-248688043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 262424664-263172368 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-234524664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247991167-248688043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 233216408-234524664 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 247991167-248688043 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 219538015-220809290 failed with response_code=403
# ...
# WARNING:rasterio._err:CPLE_AppDefined:Request for 193540522-194905531 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 207894494-208574610 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 179605369-181027742 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194232615-194905531 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 179605369-181027742 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194232615-194905531 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 165504324-166862928 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 180307944-181027742 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 165504324-166862928 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 180307944-181027742 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 151475419-152883234 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166176079-166862928 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 151475419-152883234 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166176079-166862928 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 138013733-138719743 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152159199-152883234 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 138013733-138719743 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152159199-152883234 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194232615-195632406 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 208574607-209292081 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194232615-195632406 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 208574607-209292081 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 180307944-181771130 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194905528-195632406 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 180307944-181771130 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 194905528-195632406 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166176079-167592613 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181027739-181771130 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166176079-167592613 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181027739-181771130 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152159199-153599632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166862925-167592613 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152159199-153599632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 166862925-167592613 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 138719740-139418044 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152883231-153599632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 138719740-139418044 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 152883231-153599632 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 209292078-210031709 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222187685-223616011 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 209292078-210031709 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222187685-223616011 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-182546465 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 195632403-196392205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-182546465 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 195632403-196392205 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-168372569 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-182546465 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-168372569 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-182546465 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-154329808 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-168372569 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-154329808 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-168372569 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 139418041-140117574 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-154329808 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 139418041-140117574 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-154329808 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222901201-224362555 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 236662164-238066472 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222901201-224362555 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 236662164-238066472 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 210031706-210781208 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222901201-224362555 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 210031706-210781208 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 222901201-224362555 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-183320813 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 196392202-197145123 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 181771127-183320813 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 196392202-197145123 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-169131693 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 182546462-183320813 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 167592610-169131693 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 182546462-183320813 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-155069853 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 168372566-169131693 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 153599629-155069853 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 168372566-169131693 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 140117571-140872030 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 154329805-155069853 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 140117571-140872030 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 154329805-155069853 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 223616008-225093217 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 237364105-238770937 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 223616008-225093217 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 237364105-238770937 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 210781205-211531154 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 223616008-225093217 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 210781205-211531154 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 223616008-225093217 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 182546462-184023334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 197145120-197880544 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 182546462-184023334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 197145120-197880544 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 168372566-169837700 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 183320810-184023334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 168372566-169837700 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 183320810-184023334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 154329805-155767018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169131690-169837700 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 154329805-155767018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169131690-169837700 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 140872027-141649791 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155069850-155767018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 140872027-141649791 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155069850-155767018 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 224362552-225432961 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 238066469-239109027 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 224362552-225432961 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 238066469-239109027 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 211531151-211878334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 224362552-225432961 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 211531151-211878334 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 224362552-225432961 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 183320810-184362158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 197880541-198227344 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 183320810-184362158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 197880541-198227344 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169131690-170170359 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 184023331-184362158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169131690-170170359 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 184023331-184362158 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155069850-156110052 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169837697-170170359 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155069850-156110052 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 169837697-170170359 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 141649788-142006827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155767015-156110052 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 141649788-142006827 failed with response_code=403
# WARNING:rasterio._err:CPLE_AppDefined:Request for 155767015-156110052 failed with response_code=403
# [2603203] [8/8] image mi_m_4208347_sw_17_060_20200705 | +346 tiles
# [2603203] -> /content/drive/MyDrive/michigan_unet_project/results_9puma/predictions_puma/bg_estimates_puma_2603203.csv
# [2603203] buildings 71,185 | land 94.5 km^2 | density 753.3/km^2 | built-up 12.98%
# [2603203] DONE
# ============================================================
# PUMA 2601703
# ============================================================
# [2601703] block groups 137 | tiles 2,485
# [2601703] NAIP images 20 | assigned 2,485 | fallback 0
# [2601703] [1/13] image mi_m_4208303_ne_17_060_20200705 | +92 tiles
# [2601703] [2/13] image mi_m_4208303_nw_17_060_20200702 | +65 tiles
# [2601703] [3/13] image mi_m_4308350_se_17_060_20200702 | +32 tiles
# [2601703] [4/13] image mi_m_4308350_sw_17_060_20200702 | +4 tiles
# [2601703] [5/13] image mi_m_4308351_sw_17_060_20200702 | +55 tiles
# [2601703] [6/13] image mi_m_4308358_ne_17_060_20200702 | +435 tiles
# [2601703] [7/13] image mi_m_4308358_nw_17_060_20200702 | +64 tiles
# [2601703] [8/13] image mi_m_4308358_se_17_060_20200702 | +145 tiles
# [2601703] [9/13] image mi_m_4308358_sw_17_060_20200702 | +20 tiles
# [2601703] [10/13] image mi_m_4308359_ne_17_060_20200702 | +42 tiles
# [2601703] [11/13] image mi_m_4308359_nw_17_060_20200702 | +556 tiles
# [2601703] [12/13] image mi_m_4308359_se_17_060_20200705 | +504 tiles
# [2601703] [13/13] image mi_m_4308359_sw_17_060_20200702 | +471 tiles
# [2601703] -> /content/drive/MyDrive/michigan_unet_project/results_9puma/predictions_puma/bg_estimates_puma_2601703.csv
# [2601703] buildings 51,206 | land 163.0 km^2 | density 314.1/km^2 | built-up 6.44%
# [2601703] DONE
# ============================================================
# PUMA 2602903
# ============================================================
# [2602903] block groups 138 | tiles 2,713
# [2602903] NAIP images 12 | assigned 2,713 | fallback 0
# [2602903] [1/12] image mi_m_4208323_ne_17_060_20200705 | +136 tiles
# [2602903] [2/12] image mi_m_4208323_nw_17_060_20200705 | +80 tiles
# [2602903] [3/12] image mi_m_4208323_se_17_060_20200705 | +449 tiles
# [2602903] [4/12] image mi_m_4208323_sw_17_060_20200705 | +215 tiles
# [2602903] [5/12] image mi_m_4208324_nw_17_060_20200705 | +99 tiles
# [2602903] [6/12] image mi_m_4208324_sw_17_060_20200705 | +324 tiles
# [2602903] [7/12] image mi_m_4208331_ne_17_060_20200705 | +493 tiles
# [2602903] [8/12] image mi_m_4208331_nw_17_060_20200705 | +219 tiles
# [2602903] [9/12] image mi_m_4208331_se_17_060_20200630 | +132 tiles
# [2602903] [10/12] image mi_m_4208331_sw_17_060_20200705 | +50 tiles
# [2602903] [11/12] image mi_m_4208332_nw_17_060_20200705 | +364 tiles
# [2602903] [12/12] image mi_m_4208332_sw_17_060_20200630 | +152 tiles
# [2602903] -> /content/drive/MyDrive/michigan_unet_project/results_9puma/predictions_puma/bg_estimates_puma_2602903.csv
# [2602903] buildings 64,491 | land 178.7 km^2 | density 361.0/km^2 | built-up 10.87%
# [2602903] DONE
#
# Small-group session complete.
